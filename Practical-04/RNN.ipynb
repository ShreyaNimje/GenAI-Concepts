# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense, Embedding
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# 1. Load and Tokenize Data
with open('data.txt', 'r') as f:
    data = f.read().lower().split('\n')

tokenizer = Tokenizer()
tokenizer.fit_on_texts(data)
total_words = len(tokenizer.word_index) + 1

# 2. Prepare N-gram Sequences
input_sequences = []
for line in data:
  token_list = tokenizer.texts_to_sequences([line])[0]
  for i in range(1, len(token_list)):
    input_sequences.append(token_list[:i+1])

max_seq_len = max(len(seq)for seq in input_sequences)
input_sequences = np.array(pad_sequences(input_sequences, maxlen=max_seq_len, padding='pre'))
X, y = input_sequences[:, :-1], input_sequences[:, -1]

# 3, Build and Train RNN Model
model = Sequential([
  Embedding(total_words, 10),
  SimpleRNN(50),
  Dense(total_words, activation='softmax')
])
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam')
model.fit(X, y, epochs=100, verbose=1)

#4. Predict Next word from user input
while True:
  user_text = input("Enter text (or 'quit' to exit'): ")
  if user_text.lower() == 'quit' : break

  seq = pad_sequences(tokenizer.texts_to_sequences([user_text]), maxlen=max_seq_len-1, padding='pre')
  pred_idx = np.argmax(model.predict(seq, verbose=0), axis=-1)[0]
  print(f"Predicted next word: {tokenizer.index_word.get(pred_idx, '')}\n")
# Out:
# Epoch 1/100
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:100: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 5.6805
# Epoch 2/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.4311
# Epoch 3/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.1204
# Epoch 4/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.0016
# Epoch 5/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.9778
# Epoch 6/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.9557
# Epoch 7/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.9461
# Epoch 8/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.9406
# Epoch 9/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.9393
# Epoch 10/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.9327
# Epoch 11/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.9241
# Epoch 12/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.9201
# Epoch 13/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.9156
# Epoch 14/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.9024
# Epoch 15/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.8841
# Epoch 16/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.8646
# Epoch 17/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.8356
# Epoch 18/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 4.7913
# Epoch 19/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.8178
# Epoch 20/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.6931
# Epoch 21/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.6018
# Epoch 22/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.5134
# Epoch 23/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.4204
# Epoch 24/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 4.3227
# Epoch 25/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.2252
# Epoch 26/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.1236
# Epoch 27/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.0195
# Epoch 28/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.9162
# Epoch 29/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.8129
# Epoch 30/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.7198
# Epoch 31/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.6216
# Epoch 32/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.5232
# Epoch 33/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.4335
# Epoch 34/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.3420
# Epoch 35/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.2494
# Epoch 36/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.1620
# Epoch 37/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.0742
# Epoch 38/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.9934
# Epoch 39/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.9126
# Epoch 40/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.8295
# Epoch 41/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.7515
# Epoch 42/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.6768
# Epoch 43/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.6037
# Epoch 44/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.5270
# Epoch 45/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.4581
# Epoch 46/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.3854
# Epoch 47/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.3168
# Epoch 48/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.2543
# Epoch 49/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.2076
# Epoch 50/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.1258
# Epoch 51/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.0670
# Epoch 52/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.0077
# Epoch 53/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.9560
# Epoch 54/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.9016
# Epoch 55/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.8376
# Epoch 56/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.7938
# Epoch 57/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.7355
# Epoch 58/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.6837
# Epoch 59/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.6390
# Epoch 60/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.5891
# Epoch 61/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.5456
# Epoch 62/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.5020
# Epoch 63/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.4647
# Epoch 64/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.4236
# Epoch 65/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.3806
# Epoch 66/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.3432
# Epoch 67/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.3067
# Epoch 68/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.2763
# Epoch 69/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.2318
# Epoch 70/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.2004
# Epoch 71/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.1763
# Epoch 72/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.1409
# Epoch 73/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.1163
# Epoch 74/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.0784
# Epoch 75/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.0464
# Epoch 76/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.0242
# Epoch 77/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9945
# Epoch 78/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.9727
# Epoch 79/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.9479
# Epoch 80/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.9325
# Epoch 81/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.9044
# Epoch 82/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.8828
# Epoch 83/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.8639
# Epoch 84/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.8391
# Epoch 85/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.8180
# Epoch 86/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.7977
# Epoch 87/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.7796
# Epoch 88/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.7612
# Epoch 89/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.7447
# Epoch 90/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.7243
# Epoch 91/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.7099
# Epoch 92/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.6952
# Epoch 93/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.6781
# Epoch 94/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.6665
# Epoch 95/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.6542
# Epoch 96/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.6366
# Epoch 97/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.6234
# Epoch 98/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.6182
# Epoch 99/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.6041
# Epoch 100/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5902
# Enter text (or 'quit' to exit): big
# Predicted next word: that
#
# Enter text (or 'quit' to exit): Ria
# Predicted next word: smiled
#
# Enter text (or 'quit' to exit): suddenly
# Predicted next word: ria
#
# Enter text (or 'quit' to exit): little paw
# Predicted next word: it
#
# Enter text (or 'quit' to exit): bird flew down
# Predicted next word: and
#
# Enter text (or 'quit' to exit): Thank you so much
# Predicted next word: ”
#
# Enter text (or 'quit' to exit): quit

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Embedding
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# 1. Load and Tokenize Data
with open('data.txt', 'r') as f:
    data = f.read().lower().split('\n')

tokenizer = Tokenizer()
tokenizer.fit_on_texts(data)
total_words = len(tokenizer.word_index) + 1

# 2. Prepare N-gram Sequences
input_sequences = []
for line in data:
  token_list = tokenizer.texts_to_sequences([line])[0]
  for i in range(1, len(token_list)):
    input_sequences.append(token_list[:i+1])

max_seq_len = max(len(seq)for seq in input_sequences)
input_sequences = np.array(pad_sequences(input_sequences, maxlen=max_seq_len, padding='pre'))
X, y = input_sequences[:, :-1], input_sequences[:, -1]

# 3, Build and Train RNN Model
model = Sequential([
  Embedding(total_words, 10, input_length=max_seq_len-1),
  LSTM(150),
  Dense(total_words, activation='softmax')
])
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam')
model.fit(X, y, epochs=100, verbose=1)

#4. Predict Next word from user input
while True:
  user_text = input("Enter text (or 'quit' to exit): ")
  if user_text.lower() == 'quit' : break

  seq = pad_sequences(tokenizer.texts_to_sequences([user_text]), maxlen=max_seq_len-1, padding='pre')
  pred_idx = np.argmax(model.predict(seq, verbose=0), axis=-1)[0]
  print(f"Predicted next word: {tokenizer.index_word.get(pred_idx, '')}\n")
# Out:
# Epoch 1/100
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:100: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 76ms/step - loss: 5.4393
# Epoch 2/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - loss: 5.0870
# Epoch 3/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 5.0106
# Epoch 4/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 4.9832
# Epoch 5/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 4.9697
# Epoch 6/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 4.9607
# Epoch 7/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 4.9539
# Epoch 8/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 83ms/step - loss: 4.9467
# Epoch 9/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - loss: 4.9273
# Epoch 10/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 4.9052
# Epoch 11/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - loss: 4.8716
# Epoch 12/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - loss: 4.8296
# Epoch 13/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 4.7850
# Epoch 14/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - loss: 4.7187
# Epoch 15/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 85ms/step - loss: 4.6437
# Epoch 16/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 4.5815
# Epoch 17/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 4.4956
# Epoch 18/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 4.4020
# Epoch 19/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - loss: 4.2975
# Epoch 20/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 4.1919
# Epoch 21/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 4.0862
# Epoch 22/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 78ms/step - loss: 3.9927
# Epoch 23/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 3.8717
# Epoch 24/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 3.7693
# Epoch 25/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 3.6637
# Epoch 26/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 51ms/step - loss: 3.5818
# Epoch 27/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 3.4883
# Epoch 28/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - loss: 3.4026
# Epoch 29/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 3.3227
# Epoch 30/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 3.2164
# Epoch 31/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - loss: 3.1392
# Epoch 32/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - loss: 3.0498
# Epoch 33/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 2.9693
# Epoch 34/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 2.8991
# Epoch 35/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - loss: 2.8191
# Epoch 36/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 87ms/step - loss: 2.7408
# Epoch 37/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 2.6790
# Epoch 38/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 2.5980
# Epoch 39/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 2.5350
# Epoch 40/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 2.4572
# Epoch 41/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 2.3854
# Epoch 42/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - loss: 2.3273
# Epoch 43/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 97ms/step - loss: 2.2719
# Epoch 44/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - loss: 2.2060
# Epoch 45/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 2.1427
# Epoch 46/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 2.0796
# Epoch 47/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - loss: 2.0200
# Epoch 48/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 1.9591
# Epoch 49/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 1.9008
# Epoch 50/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step - loss: 1.8492
# Epoch 51/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 1.7982
# Epoch 52/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 1.7537
# Epoch 53/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 1.7066
# Epoch 54/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 1.6599
# Epoch 55/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 1.6052
# Epoch 56/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 1.5597
# Epoch 57/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 1.5123
# Epoch 58/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 97ms/step - loss: 1.4672
# Epoch 59/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 65ms/step - loss: 1.4307
# Epoch 60/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 1.3918
# Epoch 61/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - loss: 1.3576
# Epoch 62/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - loss: 1.3139
# Epoch 63/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 1.2777
# Epoch 64/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - loss: 1.2425
# Epoch 65/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 116ms/step - loss: 1.2099
# Epoch 66/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 1.1702
# Epoch 67/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - loss: 1.1438
# Epoch 68/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 65ms/step - loss: 1.1123
# Epoch 69/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - loss: 1.0782
# Epoch 70/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - loss: 1.0491
# Epoch 71/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - loss: 1.0252
# Epoch 72/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - loss: 0.9926
# Epoch 73/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.9675
# Epoch 74/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.9539
# Epoch 75/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.9227
# Epoch 76/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.8996
# Epoch 77/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.8768
# Epoch 78/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.8512
# Epoch 79/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.8307
# Epoch 80/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - loss: 0.8081
# Epoch 81/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.7876
# Epoch 82/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.7729
# Epoch 83/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 0.7479
# Epoch 84/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.7330
# Epoch 85/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 0.7162
# Epoch 86/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 0.7022
# Epoch 87/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - loss: 0.6833
# Epoch 88/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - loss: 0.6690
# Epoch 89/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.6510
# Epoch 90/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.6380
# Epoch 91/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.6204
# Epoch 92/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.6075
# Epoch 93/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.5925
# Epoch 94/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - loss: 0.5803
# Epoch 95/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 97ms/step - loss: 0.5662
# Epoch 96/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - loss: 0.5573
# Epoch 97/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.5437
# Epoch 98/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.5335
# Epoch 99/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - loss: 0.5242
# Epoch 100/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.5097
# Enter text (or 'quit' to exit): big
# Predicted next word: afternoon
#
# Enter text (or 'quit' to exit): Ria
# Predicted next word: smiled
#
# Enter text (or 'quit' to exit): paw
# Predicted next word: is
#
# Enter text (or 'quit' to exit): suddenly
# Predicted next word: the
#
# Enter text (or 'quit' to exit): little paw
# Predicted next word: a
#
# Enter text (or 'quit' to exit): bird flew down
# Predicted next word: and
#
# Enter text (or 'quit' to exit): Thank you so much
# Predicted next word: ”
#
# Enter text (or 'quit' to exit): quit

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dense, Embedding
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# 1. Load and Tokenize Data
with open('data.txt', 'r') as f:
    data = f.read().lower().split('\n')

tokenizer = Tokenizer()
tokenizer.fit_on_texts(data)
total_words = len(tokenizer.word_index) + 1

# 2. Prepare N-gram Sequences
input_sequences = []
for line in data:
  token_list = tokenizer.texts_to_sequences([line])[0]
  for i in range(1, len(token_list)):
    input_sequences.append(token_list[:i+1])

max_seq_len = max(len(seq)for seq in input_sequences)
input_sequences = np.array(pad_sequences(input_sequences, maxlen=max_seq_len, padding='pre'))
X, y = input_sequences[:, :-1], input_sequences[:, -1]

# 3, Build and Train RNN Model
model = Sequential([
  Embedding(total_words, 10, input_length=max_seq_len-1),
  GRU(150),
  Dense(total_words, activation='softmax')
])
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam')
model.fit(X, y, epochs=100, verbose=1)

#4. Predict Next word from user input
while True:
  user_text = input("Enter text (or 'quit' to exit): ")
  if user_text.lower() == 'quit' : break

  seq = pad_sequences(tokenizer.texts_to_sequences([user_text]), maxlen=max_seq_len-1, padding='pre')
  pred_idx = np.argmax(model.predict(seq, verbose=0), axis=-1)[0]
  print(f"Predicted next word: {tokenizer.index_word.get(pred_idx, '')}\n")
# Out:
# Epoch 1/100
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:100: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - loss: 5.5806
# Epoch 2/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - loss: 5.0848
# Epoch 3/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 4.9971
# Epoch 4/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - loss: 4.9699
# Epoch 5/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 4.9691
# Epoch 6/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - loss: 4.9523
# Epoch 7/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - loss: 4.9318
# Epoch 8/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - loss: 4.8930
# Epoch 9/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - loss: 4.8298
# Epoch 10/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - loss: 4.7461
# Epoch 11/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - loss: 4.6550
# Epoch 12/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 112ms/step - loss: 4.5644
# Epoch 13/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 4.4430
# Epoch 14/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - loss: 4.3142
# Epoch 15/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 4.1647
# Epoch 16/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 4.0247
# Epoch 17/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 3.8674
# Epoch 18/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 3.7216
# Epoch 19/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - loss: 3.5637
# Epoch 20/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 98ms/step - loss: 3.4198
# Epoch 21/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - loss: 3.2720
# Epoch 22/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 65ms/step - loss: 3.1340
# Epoch 23/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - loss: 2.9950
# Epoch 24/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - loss: 2.8571
# Epoch 25/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - loss: 2.7227
# Epoch 26/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 118ms/step - loss: 2.6018
# Epoch 27/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 2.4632
# Epoch 28/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - loss: 2.3395
# Epoch 29/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 2.2126
# Epoch 30/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - loss: 2.0922
# Epoch 31/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 1.9692
# Epoch 32/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 1.8625
# Epoch 33/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - loss: 1.7512
# Epoch 34/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 1.6493
# Epoch 35/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - loss: 1.5492
# Epoch 36/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - loss: 1.4572
# Epoch 37/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 65ms/step - loss: 1.3726
# Epoch 38/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 1.2909
# Epoch 39/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 1.2185
# Epoch 40/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - loss: 1.1444
# Epoch 41/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - loss: 1.0752
# Epoch 42/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 1.0147
# Epoch 43/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.9572
# Epoch 44/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.9053
# Epoch 45/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.8612
# Epoch 46/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 0.8120
# Epoch 47/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - loss: 0.7729
# Epoch 48/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 98ms/step - loss: 0.7357
# Epoch 49/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - loss: 0.7026
# Epoch 50/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 0.6663
# Epoch 51/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - loss: 0.6388
# Epoch 52/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - loss: 0.6095
# Epoch 53/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - loss: 0.5853
# Epoch 54/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - loss: 0.5602
# Epoch 55/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 100ms/step - loss: 0.5428
# Epoch 56/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - loss: 0.5161
# Epoch 57/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - loss: 0.5012
# Epoch 58/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 0.4830
# Epoch 59/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.4671
# Epoch 60/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - loss: 0.4525
# Epoch 61/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - loss: 0.4364
# Epoch 62/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - loss: 0.4251
# Epoch 63/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - loss: 0.4118
# Epoch 64/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 0.3971
# Epoch 65/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - loss: 0.3889
# Epoch 66/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.3776
# Epoch 67/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.3667
# Epoch 68/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 111ms/step - loss: 0.3577
# Epoch 69/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 0.3501
# Epoch 70/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - loss: 0.3389
# Epoch 71/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.3295
# Epoch 72/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - loss: 0.3222
# Epoch 73/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - loss: 0.3180
# Epoch 74/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 103ms/step - loss: 0.3083
# Epoch 75/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 0.3045
# Epoch 76/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 0.2959
# Epoch 77/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.2909
# Epoch 78/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.2882
# Epoch 79/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - loss: 0.2816
# Epoch 80/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - loss: 0.2773
# Epoch 81/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - loss: 0.2706
# Epoch 82/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 0.2643
# Epoch 83/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 0.2614
# Epoch 84/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - loss: 0.2568
# Epoch 85/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - loss: 0.2544
# Epoch 86/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 65ms/step - loss: 0.2470
# Epoch 87/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 137ms/step - loss: 0.2447
# Epoch 88/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 0.2446
# Epoch 89/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - loss: 0.2419
# Epoch 90/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 0.2350
# Epoch 91/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.2318
# Epoch 92/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - loss: 0.2292
# Epoch 93/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - loss: 0.2285
# Epoch 94/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 124ms/step - loss: 0.2246
# Epoch 95/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 65ms/step - loss: 0.2212
# Epoch 96/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 0.2228
# Epoch 97/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 0.2178
# Epoch 98/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step - loss: 0.2165
# Epoch 99/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.2146
# Epoch 100/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 100ms/step - loss: 0.2142
# Enter text (or 'quit' to exit): Ria
# Predicted next word: and
#
# Enter text (or 'quit' to exit): suddenly
# Predicted next word: a
#
# Enter text (or 'quit' to exit): little paw
# Predicted next word: went
#
# Enter text (or 'quit' to exit): big
# Predicted next word: played
#
# Enter text (or 'quit' to exit): Thank you so much
# Predicted next word: ”
#
# Enter text (or 'quit' to exit): bird flew down
# Predicted next word: and
#
# Enter text (or 'quit' to exit): quit
